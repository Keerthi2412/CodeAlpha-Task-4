# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv("cleaned_dataset.csv")
df.head()
# Out:
#                                                 name  \
# 0  OnePlus Nord CE 2 Lite 5G Blue Tide 6GB RAM 12...
# 1  OnePlus Bullets Z2 Bluetooth Wireless in Ear E...
# 2  Samsung Galaxy M33 5G Mystique Green 6GB 128GB...
# 3  OnePlus Nord CE 2 Lite 5G Black Dusk 6GB RAM 1...
# 4  Redmi 10 Power Sporty Orange 8GB RAM 128GB Sto...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/71AvQd3Vzq...
# 1  https://m.media-amazon.com/images/I/51UhwaQXCp...
# 2  https://m.media-amazon.com/images/I/81I3w4J6yj...
# 3  https://m.media-amazon.com/images/I/71V--WZVUI...
# 4  https://m.media-amazon.com/images/I/81OZGH4fZi...
#
#                                                 link  no_of_ratings  \
# 0  https://www.amazon.in/OnePlus-Nord-Lite-128GB-...       113956.0
# 1  https://www.amazon.in/Oneplus-Bluetooth-Wirele...        90304.0
# 2  https://www.amazon.in/Samsung-Mystique-Storage...        24863.0
# 3  https://www.amazon.in/OnePlus-Nord-Black-128GB...       113956.0
# 4  https://www.amazon.in/Redmi-Power-Sporty-Orang...          625.0
#
#    discount_price  actual_price  rating  \
# 0         18999.0       19999.0     1.0
# 1          1999.0        2299.0     5.0
# 2         15999.0       24999.0     1.0
# 3         18999.0       19999.0     5.0
# 4         10999.0       18999.0     1.0
#
#                                          review_text    brand  \
# 0  Very bad experience with this device xr phone....  OnePlus
# 1  Amazing phone with amazing camera coming from ...  OnePlus
# 2  So I got the device XR just today. The product...  Samsung
# 3  I've been an android user all my life until I ...  OnePlus
# 4  I was delivered a phone that did not work imme...    Redmi
#
#                                  cleaned_review_text sentiment
# 0  bad experience device xr phone back camera fou...  Negative
# 1  amazing phone amazing camera coming device plu...  Positive
# 2  got device xr today product look amazing unfor...  Negative
# 3  ive android user life decided try device xr io...  Positive
# 4  delivered phone work immediately removing box ...  Negative

# %%
import re 

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-z\s]', '',text)
    return text
    
df['clean_product'] = df['review_text'].apply(clean_text)

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\keerthi\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\keerthi\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\keerthi\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\keerthi\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\keerthi\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\keerthi\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\keerthi\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)

# %%
# !python -m textblob.download_corpora
# Out:
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\KEERTHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\KEERTHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\KEERTHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\KEERTHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\KEERTHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\KEERTHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
from textblob import TextBlob

text = TextBlob("Jupyter Notebook makes Python easy")
print(text.sentiment)
# Out:
# Sentiment(polarity=0.43333333333333335, subjectivity=0.8333333333333334)

# %%
from textblob import TextBlob

text = TextBlob("Python is an Object oriented language")
print(text.sentiment)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
df['cleaned_review_text'] = df['cleaned_review_text'].fillna('')

# %%
from textblob import TextBlob
text = TextBlob("Jupyter Notebook makes Python easy")
print(text.sentiment)
def get_sentiment(text):
    if not isinstance(text, str) or text.strip() == "":
        return 'Neutral'
    polarity = TextBlob(text).sentiment.polarity
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'
# Out:
# Sentiment(polarity=0.43333333333333335, subjectivity=0.8333333333333334)

# %%
df['Sentiment'] = df['cleaned_review_text'].apply(get_sentiment)
get_sentiment("I love using Jupyter Notebook")
# Out:
# 'Positive'

# %%
df['Sentiment'] = df['cleaned_review_text'].apply(get_sentiment)
get_sentiment("This is the worst experience")
# Out:
# 'Negative'

# %%
df['Sentiment'] = df['cleaned_review_text'].apply(get_sentiment)
get_sentiment("This is a software too")

# %%
from textblob import TextBlob
def sentiment_details(text):
    blob = TextBlob(text)
    return 
    {
        "Text": text,
        "Polarity": blob.sentiment.polarity,
        "Sentiment": get_sentiment(text)
    }
sentiment_details("The Quality of the Product is very high")
sentiment_details("This is the worst experience")
sentiment_details("The product was delivered yesterday")
samples = [
    "The Quality of the Product is very high",
    "This is the worst experience",
    "The product was delivered yesterday"
]
for s in samples: 
    print(s,"->",get_sentiment(s))
# Out:
# The Quality of the Product is very high -> Positive
# This is the worst experience -> Negative
# The product was delivered yesterday -> Neutral

# %%
df['Sentiment'] = df['cleaned_review_text'].apply(get_sentiment)
df[['cleaned_review_text','Sentiment']].head()
# Out:
#                                  cleaned_review_text Sentiment
# 0  bad experience device xr phone back camera fou...  Negative
# 1  amazing phone amazing camera coming device plu...  Positive
# 2  got device xr today product look amazing unfor...  Positive
# 3  ive android user life decided try device xr io...  Positive
# 4  delivered phone work immediately removing box ...  Positive
